# %%
from matplotlib import pyplot as plt

x = [1,345,334,643,634,6,262,346,436,236]
y = [534,634,263,26,346,432,62,63,426,3]

plt.scatter(x, y)
for i in range(len(x)):
    label ="(" + str(x[i]) + "," + str(y[i])+ ")"
    plt.annotate(label, xy=(x[i],y[i]))

plt.show()
